# %% [markdown]
# # NOTES

# %% [markdown]
# - This is all just proof-of-concept stuff...definitely not the final data set yet

# %% [markdown]
# # Setup

# %%
import os
import numpy as np
import pandas as pd
import pandasql as ps

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
os.chdir("/Users/tessleggio/GoogleDrive/GeorgiaTech/2018-Fall/01-ISYE-6414/6414Project")
print(os.getcwd())
# Out:
# /Users/tessleggio/GoogleDrive/GeorgiaTech/2018-Fall/01-ISYE-6414/6414Project

# %%
aqi = pd.read_csv("cleaned_data/aqi_2016.csv")
population = pd.read_csv("cleaned_data/population.csv")
#powerplant = pd.read_csv("cleaned_data/powerplant_agg.csv")
powerplant = pd.read_csv("cleaned_data/powerplant_2016.csv")
temps = pd.read_csv("cleaned_data/temps.csv")

# %%
display(aqi.head())
display(population.tail())
display(powerplant.head())
display(temps.head())
# Out:
#      State   County  State Code  County Code                        Date  AQI  \
# 0  alabama  baldwin           1            3  2016-01-01 00:00:00.000000   33
# 1  alabama  baldwin           1            3  2016-01-04 00:00:00.000000   22
# 2  alabama  baldwin           1            3  2016-01-07 00:00:00.000000   28
# 3  alabama  baldwin           1            3  2016-01-10 00:00:00.000000   13
# 4  alabama  baldwin           1            3  2016-01-13 00:00:00.000000   36
#
#   Category Defining Parameter Defining Site  Number of Sites Reporting  ...    \
# 0     Good              PM2.5   01-003-0010                          1  ...
# 1     Good              PM2.5   01-003-0010                          1  ...
# 2     Good              PM2.5   01-003-0010                          1  ...
# 3     Good              PM2.5   01-003-0010                          1  ...
# 4     Good              PM2.5   01-003-0010                          1  ...
#
# ...

# %% [markdown]
# # Merge Data

# %%
merged = pd.merge(aqi, population, on=['State', 'County','Year'], how='left')
merged.drop(['StateNum','CountyNum','Region'], axis=1, inplace=True)
merged = pd.merge(merged, powerplant, on=['State', 'County','Year','Month'], how='left')
merged = pd.merge(merged, temps, on=['State', 'County','Year','Month'], how='left')
display(merged[10000:10200])
# Out:
#          State  County  State Code_x  County Code_x  \
# 10000  alabama  mobile             1             97
# 10001  alabama  mobile             1             97
# 10002  alabama  mobile             1             97
# 10003  alabama  mobile             1             97
# 10004  alabama  mobile             1             97
# 10005  alabama  mobile             1             97
# 10006  alabama  mobile             1             97
# 10007  alabama  mobile             1             97
# 10008  alabama  mobile             1             97
# 10009  alabama  mobile             1             97
# 10010  alabama  mobile             1             97
# 10011  alabama  mobile             1             97
# 10012  alabama  mobile             1             97
# 10013  alabama  mobile             1             97
# 10014  alabama  mobile             1             97
# 10015  alabama  mobile             1             97
# 10016  alabama  mobile             1             97
# ...

# %%
print(len(merged))
# Out:
# 3777539

# %%
merged.to_csv("./cleaned_data/MERGED.csv", index=None, header=True)
